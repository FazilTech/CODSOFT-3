# %% [markdown]
# # Importing the Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
sns.set()

# %% [markdown]
# # Import DataSet

# %%
raw_data = pd.read_csv("IRIS.csv")
print(raw_data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
raw_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Check for NULL values

# %%
raw_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# no null values
data = raw_data.copy()
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Visualize the DataSet

# %%
sns.pairplot(raw_data, hue='species')
plt.show()

# %% [markdown]
# # Spliting of Datas

# %%
inputs = data.drop('species', axis=1)
target = data['species']
inputs
target
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, target, test_size=0.3, random_state = 2)
inputs.shape, x_train.shape, x_test.shape
# Out:
# ((150, 4), (105, 4), (45, 4))

# %% [markdown]
# # Training the DataSet

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Prediction for Training Datas

# %%
# training the train set datas
x_train_prediction = knn.predict(x_train)
x_train_prediction
# Out:
# array(['Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
# ...

# %%
# Checking the accuracy of the train set
train_accuracy = accuracy_score(y_train, x_train_prediction)
train_accuracy
# Out:
# 0.9428571428571428

# %% [markdown]
# # Prediction for Test Dataset

# %%
# Training the Test dataSet
x_test_prediction = knn.predict(x_test)
x_test_prediction
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa'], dtype=object)

# %%
# Checking the accuracy score
test_accuracy = accuracy_score(y_test, x_test_prediction)
test_accuracy
# Out:
# 1.0

# %% [markdown]
# # Classification Report

# %%
print(classification_report(y_test, x_test_prediction))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # Testing for Iris-Virginica

# %%
data.iloc[100:]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# ...

# %%
# Testing with given data
new_data = pd.DataFrame({"sepal_length":[5.8],"sepal_width":2.7, "petal_length":5.1, "petal_width":1.90 })
new_data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.8          2.7           5.1          1.9

# %%
prediction=(knn.predict(new_data))
prediction
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
# testing with new data
new_data = pd.DataFrame({"sepal_length":[5.3],"sepal_width":2.2, "petal_length":4.9, "petal_width":1.87 })
new_data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.3          2.2           4.9         1.87

# %%
prediction=(knn.predict(new_data))
prediction
# Out:
# array(['Iris-virginica'], dtype=object)

# %% [markdown]
# # Testing for Iris-setosa

# %%
data.iloc[1:50]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# ...

# %%
# Testing with given data
new_data = pd.DataFrame({"sepal_length":[5.1],"sepal_width":3.8, "petal_length":1.6, "petal_width":0.2 })
new_data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.8           1.6          0.2

# %%
prediction=(knn.predict(new_data))
prediction
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
# testing with new data
new_data = pd.DataFrame({"sepal_length":[5.3],"sepal_width":3.1, "petal_length":2.0, "petal_width":0.3 })
new_data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.3          3.1           2.0          0.3

# %%
prediction=(knn.predict(new_data))
prediction
# Out:
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# # Testing for Iris-versicolor

# %%
data.iloc[50:100]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 55           5.7          2.8           4.5          1.3  Iris-versicolor
# 56           6.3          3.3           4.7          1.6  Iris-versicolor
# 57           4.9          2.4           3.3          1.0  Iris-versicolor
# 58           6.6          2.9           4.6          1.3  Iris-versicolor
# 59           5.2          2.7           3.9          1.4  Iris-versicolor
# 60           5.0          2.0           3.5          1.0  Iris-versicolor
# 61           5.9          3.0           4.2          1.5  Iris-versicolor
# ...

# %%
# testing with given data
new_data = pd.DataFrame({"sepal_length":[5.7],"sepal_width":2.8, "petal_length":4.1, "petal_width":1.3 })
new_data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.7          2.8           4.1          1.3

# %%
prediction=(knn.predict(new_data))
prediction
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
# testing with new data
new_data = pd.DataFrame({"sepal_length":[5.5],"sepal_width":3.0, "petal_length":4.3, "petal_width":1.5 })
new_data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.5          3.0           4.3          1.5

# %%
prediction=(knn.predict(new_data))
prediction
# Out:
# array(['Iris-versicolor'], dtype=object)
